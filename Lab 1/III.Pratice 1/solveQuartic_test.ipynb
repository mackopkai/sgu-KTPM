# %%
# !g++ solveQuartic.cpp -o solveQuartic

# %%
test_cases = [
    (0, 0, 0),
    (0, 0, 1),
    (0, 1, -4),
    (1, -5, 6),
    (1, 0, 1),
    ]

# %%
for t in test_cases:
    print(f"Test solveQuartic{t}:")
    input_str = f"{t[0]} {t[1]} {t[2]}"
    # !echo {input_str} | ./solveQuartic
# Out:
# Test solveQuartic(0, 0, 0):
# Infinite solutions.
# Test solveQuartic(0, 0, 1):
# No solution.
# Test solveQuartic(0, 1, -4):
# The equation has 2 real solution(s): 2 -2
# Test solveQuartic(1, -5, 6):
# The equation has 4 real solution(s): 1.73205 -1.73205 1.41421 -1.41421
# Test solveQuartic(1, 0, 1):
# No solution.
