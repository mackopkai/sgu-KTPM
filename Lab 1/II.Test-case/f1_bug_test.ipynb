# %%
# !g++ f1_bug.cpp -o f1_bug

# %%
test_values = [12, 9, -1]
for x in test_values:
    print("Test f1_bug({x}):")
    # !echo {x} | ./f1_bug
# Out:
# Test f1_bug({x}):
# 24
# Test f1_bug({x}):
# -9
# Test f1_bug({x}):
# -2
