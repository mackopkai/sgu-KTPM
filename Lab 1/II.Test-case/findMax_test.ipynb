# %%
# !g++ findMax.cpp -o findMax

# %%
test_cases = [
        (5, 3, 1),
        (2, 7, 4),
        (1, 3, 9),
        (5, 5, 3)
    ]

# %%
for t in test_cases:
        print(f"Test findMax{t}:")
        input_str = f"{t[0]} {t[1]} {t[2]}"
        # !echo {input_str} | ./findMax
# Out:
# Test findMax(5, 3, 1):
# 5
# Test findMax(2, 7, 4):
# 7
# Test findMax(1, 3, 9):
# 9
# Test findMax(5, 5, 3):
# 0
