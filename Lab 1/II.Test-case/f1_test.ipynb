# %%
# !g++ f1.cpp -o f1

# %%
# Chạy các test case
test_values = [12, 10]
for x in test_values:
    print(f"Test f1({x}):")  # In ra test case
    # Chạy câu lệnh shell trong Jupyter, dùng f-string đúng cách
    # !echo {x} | ./f1
# Out:
# Test f1(12):
# 24
# Test f1(10):
# -10
